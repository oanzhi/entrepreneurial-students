# %% [markdown]
# Прогноз предприимчивости студентов

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data.csv')

# %%
df.head()
# Out:
#         EducationSector IndividualProject  Age Gender City Influenced  \
# 0  Engineering Sciences                No   19   Male  Yes         No
# 1  Engineering Sciences               Yes   22   Male   No        Yes
# 2  Engineering Sciences                No   18   Male  Yes         No
# 3  Engineering Sciences               Yes   20   Male  Yes        Yes
# 4  Engineering Sciences               Yes   19   Male  Yes        Yes
#
#    Perseverance  DesireToTakeInitiative  Competitiveness  SelfReliance  \
# 0             2                       2                3             3
# 1             3                       3                3             4
# 2             3                       4                3             3
# 3             3                       3                3             3
# 4             2                       3                3             3
#
#    StrongNeedToAchieve  SelfConfidence  GoodPhysicalHealth MentalDisorder  \
# ...

# %%
df.shape
# Out:
# (219, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 219 entries, 0 to 218
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   EducationSector         219 non-null    object
#  1   IndividualProject       219 non-null    object
#  2   Age                     219 non-null    int64
#  3   Gender                  219 non-null    object
#  4   City                    219 non-null    object
#  5   Influenced              219 non-null    object
#  6   Perseverance            219 non-null    int64
#  7   DesireToTakeInitiative  219 non-null    int64
#  8   Competitiveness         219 non-null    int64
#  9   SelfReliance            219 non-null    int64
#  10  StrongNeedToAchieve     219 non-null    int64
#  11  SelfConfidence          219 non-null    int64
#  12  GoodPhysicalHealth      219 non-null    int64
#  13  MentalDisorder          219 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# EducationSector            0
# IndividualProject          0
# Age                        0
# Gender                     0
# City                       0
# Influenced                 0
# Perseverance               0
# DesireToTakeInitiative     0
# Competitiveness            0
# SelfReliance               0
# StrongNeedToAchieve        0
# SelfConfidence             0
# GoodPhysicalHealth         0
# MentalDisorder             0
# KeyTraits                  0
# ReasonsForLack            91
# y                          0
# dtype: int64

# %%
df = df.drop(columns=['ReasonsForLack'])

# %%
df.describe()
# Out:
#               Age  Perseverance  DesireToTakeInitiative  Competitiveness  \
# count  219.000000    219.000000              219.000000       219.000000
# mean    19.753425      3.351598                3.621005         3.589041
# std      1.289842      0.995234                1.152467         1.110859
# min     17.000000      1.000000                1.000000         1.000000
# 25%     19.000000      3.000000                3.000000         3.000000
# 50%     20.000000      3.000000                4.000000         4.000000
# 75%     20.000000      4.000000                5.000000         4.500000
# max     26.000000      5.000000                5.000000         5.000000
#
#        SelfReliance  StrongNeedToAchieve  SelfConfidence  GoodPhysicalHealth  \
# count    219.000000           219.000000      219.000000          219.000000
# mean       3.721461             3.908676        3.575342            3.561644
# std        1.053629             1.023068        1.120098            1.100287
# ...

# %%
categorical = df.select_dtypes(include = ['object']).columns

# %%
numerical = df.select_dtypes(exclude = ['object']).columns

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
for i in range(len(categorical)):
    plt.figure(i)
    sns.countplot(x=categorical[i], data=df)

# %%
for i in range(len(numerical)):
    plt.figure(i)
    sns.countplot(x=numerical[i], data=df)

# %%
for i in range(len(numerical)):
    plt.figure(i)
    sns.boxplot(x=numerical[i], data=df)

# %%
plt.figure(figsize=(16, 8))
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
for i in range(len(categorical)):
    plt.figure(i)
    sns.countplot(y=categorical[i], data=df, hue='y')

# %%
sns.pairplot(df, hue = 'Age')

# %%
df = pd.get_dummies(df)

# %%
df.head()
# Out:
#    Age  Perseverance  DesireToTakeInitiative  Competitiveness  SelfReliance  \
# 0   19             2                       2                3             3
# 1   22             3                       3                3             4
# 2   18             3                       4                3             3
# 3   20             3                       3                3             3
# 4   19             2                       3                3             3
#
#    StrongNeedToAchieve  SelfConfidence  GoodPhysicalHealth  y  \
# 0                    2               2                   3  1
# 1                    4               3                   4  0
# 2                    3               4                   4  0
# 3                    4               3                   3  0
# 4                    4               3                   2  1
#
#    EducationSector_Art, Music or Design  ...  City_Yes  Influenced_No  \
# ...

# %%
X = df.drop(['y'], axis=1)
y = df['y']

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.preprocessing import StandardScaler

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (153, 32) (153,)
# (66, 32) (66,)

# %%
ss = StandardScaler()
X_train_s = ss.fit_transform(X_train)
X_test_s = ss.fit_transform(X_test)

# %%
X_train.head()
# Out:
#      Age  Perseverance  DesireToTakeInitiative  Competitiveness  SelfReliance  \
# 208   20             4                       5                4             4
# 14    20             2                       1                2             3
# 217   19             1                       2                2             3
# 151   19             2                       3                2             3
# 56    20             3                       4                3             5
#
#      StrongNeedToAchieve  SelfConfidence  GoodPhysicalHealth  \
# 208                    5               5                   5
# 14                     3               2                   3
# 217                    3               2                   2
# 151                    2               2                   1
# 56                     4               5                   3
#
#      EducationSector_Art, Music or Design  \
# 208                                     0
# ...

# %%
X_train_s[:5]
# Out:
# array([[ 0.1455395 ,  0.67691295,  1.19023807,  0.35164489,  0.23948206,
#          1.08180633,  1.25751276,  1.30937566, -0.29172998, -0.44194174,
#          0.89442719, -0.16384638, -0.08111071, -0.08111071, -0.25      ,
#         -0.31736324, -0.11508707,  1.22808661, -1.22808661, -0.61512469,
#          0.61512469, -0.45246482,  0.45246482,  1.70970083, -1.70970083,
#          0.65567259, -0.65567259, -0.59496412, -0.72801099, -0.20203051,
#          2.2101166 , -0.47328638],
#        [ 0.1455395 , -1.39444068, -2.38047614, -1.41234422, -0.72474833,
#         -0.91236678, -1.47802448, -0.49543944, -0.29172998, -0.44194174,
#         -1.11803399, -0.16384638, -0.08111071, -0.08111071, -0.25      ,
#          3.15096357, -0.11508707,  1.22808661, -1.22808661, -0.61512469,
#          0.61512469,  2.2101166 , -2.2101166 , -0.58489765,  0.58489765,
#          0.65567259, -0.65567259,  1.68077363, -0.72801099, -0.20203051,
#         -0.45246482, -0.47328638],
# ...

# %%
X_train_s.std()
# Out:
# 1.0

# %%
lda = LinearDiscriminantAnalysis()

# %%
lda.fit(X_train_s, y_train)
# Out:
# LinearDiscriminantAnalysis()

# %%
pred_train = lda.predict(X_train_s)

# %%
confusion_matrix(y_train, pred_train)
# Out:
# array([[65, 22],
#        [24, 42]], dtype=int64)

# %%
accuracy_score(y_train, pred_train)
# Out:
# 0.6993464052287581

# %%
pred_test = lda.predict(X_test_s)

# %%
confusion_matrix(y_test, pred_test)
# Out:
# array([[26, 15],
#        [13, 12]], dtype=int64)

# %%
accuracy_score(y_test, pred_test)
# Out:
# 0.5757575757575758

# %%
lda.predict_proba(X_test_s)[:5]
# Out:
# array([[0.22989833, 0.77010167],
#        [0.5820651 , 0.4179349 ],
#        [0.33680716, 0.66319284],
#        [0.42644872, 0.57355128],
#        [0.78502206, 0.21497794]])

# %%
y_test[:5]
# Out:
# 165    1
# 34     1
# 35     0
# 201    1
# 160    0
# Name: y, dtype: int64
